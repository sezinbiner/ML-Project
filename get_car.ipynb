# %% [markdown]
# <a href="https://colab.research.google.com/github/sezinbiner/ML-Project/blob/prediction-models/get_car.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
sez = np.arange(1,200)

# %%
list_of_cars = []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://www.fordikinciel.com/araba-fiyatlari?p=6"
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
links = soup.find_all("a", class_="anaResimLink")
links[0]["href"]
for link in links:
  print(link["href"])
  path = "https://www.fordikinciel.com/"
  path = path + link["href"]
  print(path)
  from urllib.request import urlopen
  from bs4 import BeautifulSoup
  url = path
  html = urlopen(url)
  soup = BeautifulSoup(html, 'lxml')
  car = []
  price = soup.find_all('span', class_ = 'price')
  print(price[0].text.split(" ")[-1])
  price = price[0].text.split(" ")[-1]
  car.append(price)
  spans = soup.find_all('span')
  indexes = [17,18,20,21,23,24,25,26,27,28,29,31,32]
  i = 0
  for s in spans:
    if(i in indexes):
      print(s.text.split(" ")[-1])
      car.append(s.text.split(" ")[-1])
    i = i+1
  list_of_cars.append(car)
# Out:
# renault-fluence-15_dci_touch_edc-2015-araba-49745
# https://www.fordikinciel.com/renault-fluence-15_dci_touch_edc-2015-araba-49745
# 139.500
# RENAULT
# FLUENCE
# 2015
# 130.180
# Otomatik
# Dizel
# -
# 110
# 1461
# 1389
# Sedan
# Otomobil
# Binek
# mercedes-e_serisi-e_250_editione_otomatik-2015-araba-49749
# https://www.fordikinciel.com/mercedes-e_serisi-e_250_editione_otomatik-2015-araba-49749
# 602.500
# MERCEDES
# SERISI
# 2015
# 101.735
# Otomatik
# Dizel
# -
# 211
# 1991
# 1680
# Sedan
# Otomobil
# Binek
# fiat-egea-16_16v_multijet_ii_startstop_urban_plus-2016-araba-49751
# https://www.fordikinciel.com/fiat-egea-16_16v_multijet_ii_startstop_urban_plus-2016-araba-49751
# 153.500
# FIAT
# EGEA
# 2016
# 122.907
# Otomatik
# Dizel
# -
# 118
# 1598
# 1295
# Hatchback
# Otomobil
# Binek
# volkswagen-passat-14_tsi_bluemotion_comfortline_dsg-2017-araba-49924
# https://www.fordikinciel.com/volkswagen-passat-14_tsi_bluemotion_comfortline_dsg-2017-araba-49924
# 267.500
# VOLKSWAGEN
# ...

# %%
list_of_cars

# %%
len(list_of_cars)
# Out:
# 126

# %%
df = pd.DataFrame(data = list_of_cars)

# %%
df
# Out:
#           0           1        2     3   ...    10         11        12     13
# 0    298.500        AUDI       A3  2018  ...  1290      Sedan  Otomobil  Binek
# 1    231.500  VOLKSWAGEN     POLO  2019  ...  1179  Hatchback  Otomobil  Binek
# 2    272.500        FORD     KUGA  2018  ...  1605      Sedan  Otomobil  Binek
# 3    137.500     PEUGEOT      208  2016  ...  1168  Hatchback  Otomobil  Binek
# 4    166.000        FORD    FOCUS  2017  ...  1269  Hatchback  Otomobil  Binek
# ..       ...         ...      ...   ...  ...   ...        ...       ...    ...
# 121  262.500       SKODA   SUPERB  2016  ...  1480  Hatchback  Otomobil  Binek
# 122  142.500     RENAULT  FLUENCE  2016  ...  1389      Sedan  Otomobil  Binek
# 123  422.500        AUDI       A4  2017  ...  1480      Sedan  Otomobil  Binek
# 124  652.500  VOLKSWAGEN   PASSAT  2019  ...  1554      Sedan  Otomobil  Binek
# 125  266.500        FORD    FOCUS  2019  ...  1358      Sedan  Otomobil  Binek
#
# [126 rows x 14 columns]

# %%
df.to_excel("output.xlsx")
