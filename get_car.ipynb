# %% [markdown]
# <a href="https://colab.research.google.com/github/sezinbiner/ML-Project/blob/prediction-models/get_car.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
sez = np.arange(1,200)
df = pd.DataFrame(columns = ["id", "Marka", "Model", "Fiyat"])

# %%
list_of_cars = []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://www.fordikinciel.com/araba-fiyatlari"
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
links = soup.find_all("a", class_="anaResimLink")
links[0]["href"]
for link in links:
  print(link["href"])
  path = "https://www.fordikinciel.com/"
  path = path + link["href"]
  print(path)
  from urllib.request import urlopen
  from bs4 import BeautifulSoup
  url = path
  html = urlopen(url)
  soup = BeautifulSoup(html, 'lxml')
  car = []
  price = soup.find_all('span', class_ = 'price')
  print(price[0].text.split(" ")[-1])
  price = price[0].text.split(" ")[-1]
  car.append(price)
  spans = soup.find_all('span')
  indexes = [17,18,20,21,23,24,25,26,27,28,29,31,32]
  i = 0
  for s in spans:
    if(i in indexes):
      print(s.text.split(" ")[-1])
      car.append(s.text.split(" ")[-1])
    i = i+1
  list_of_cars.append(car)
# Out:
# audi-a3-16_tdi_design_line_s_tronic-2018-araba-47744
# https://www.fordikinciel.com/audi-a3-16_tdi_design_line_s_tronic-2018-araba-47744
# 298.500
# AUDI
# A3
# 2018
# 62.317
# Otomatik
# Dizel
# Lacivert
# 109
# 1598
# 1290
# Sedan
# Otomobil
# Binek
# volkswagen-polo-16_tdi_comfortline_dsg-2019-araba-48271
# https://www.fordikinciel.com/volkswagen-polo-16_tdi_comfortline_dsg-2019-araba-48271
# 231.500
# VOLKSWAGEN
# POLO
# 2019
# 15.426
# Otomatik
# Dizel
# Gri
# 90
# 1598
# 1179
# Hatchback
# Otomobil
# Binek
# ford-kuga-15_tdci_style_powershift-2018-araba-48275
# https://www.fordikinciel.com/ford-kuga-15_tdci_style_powershift-2018-araba-48275
# 272.500
# FORD
# KUGA
# 2018
# 35.106
# Otomatik
# Dizel
# Gri
# 118
# 1499
# 1605
# Sedan
# Otomobil
# Binek
# peugeot-208-12_puretech_active_etg5-2016-araba-49637
# https://www.fordikinciel.com/peugeot-208-12_puretech_active_etg5-2016-araba-49637
# 137.500
# PEUGEOT
# 208
# 2016
# 98.690
# Otomatik
# Benzin
# DİĞER
# 82
# 1199
# 1168
# Hatchback
# Otomobil
# Binek
# ford-focus-16_ti_vct_trend_x-2017-araba-50205
# https://www.fordikinciel.com/ford-focus-16_ti_vct_trend_x-2017-araba-50205
# 166.000
# FORD
# FOCUS
# 2017
# 56.075
# Manuel
# Benzin
# Beyaz
# 125
# 1596
# 1269
# Hatchback
# Otomobil
# Binek
# land_rover-discovery-30_sdv6_hse_otomatik-2010-araba-50869
# https://www.fordikinciel.com/land_rover-discovery-30_sdv6_hse_otomatik-2010-araba-50869
# 465.000
# ROVER
# DISCOVERY
# 2010
# 182.087
# Otomatik
# Dizel
# Beyaz
# 245
# 2993
# 2583
# Wagon-Kombi
# Otomobil
# Binek
# mercedes-c_serisi-c_200_bluetec_amg-2018-araba-54048
# https://www.fordikinciel.com/mercedes-c_serisi-c_200_bluetec_amg-2018-araba-54048
# 533.000
# MERCEDES
# SERISI
# 2018
# 33.122
# Otomatik
# Benzin
# Beyaz
# 184
# 1598
# 1485
# Sedan
# Otomobil
# Binek
# opel-astra-15_d_edition-2020-araba-56656
# https://www.fordikinciel.com/opel-astra-15_d_edition-2020-araba-56656
# 231.500
# OPEL
# ASTRA
# 2020
# 36.955
# Otomatik
# Dizel
# Kırmızı
# 122
# 1496
# 0
# Hatchback
# Otomobil
# Binek
# skoda-superb-16_tdi_greentec_style_dsg-2016-araba-56660
# https://www.fordikinciel.com/skoda-superb-16_tdi_greentec_style_dsg-2016-araba-56660
# 273.500
# SKODA
# SUPERB
# 2016
# 89.976
# Otomatik
# Dizel
# Beyaz
# 120
# 1598
# 1480
# Hatchback
# Otomobil
# Binek
# ford-mondeo-16_tdci_titanium-2017-araba-57470
# https://www.fordikinciel.com/ford-mondeo-16_tdci_titanium-2017-araba-57470
# 236.500
# FORD
# MONDEO
# 2017
# 109.203
# Manuel
# Dizel
# Kırmızı
# 115
# 1560
# 1493
# Sedan
# Otomobil
# Binek
# skoda-octavia-16_tdi_greentec_style_dsg-2017-araba-57473
# https://www.fordikinciel.com/skoda-octavia-16_tdi_greentec_style_dsg-2017-araba-57473
# 264.500
# SKODA
# OCTAVIA
# 2017
# 74.285
# Otomatik
# Dizel
# Beyaz
# 110
# 1598
# 1245
# Hatchback
# Otomobil
# Binek
# opel-corsa-14_essentia_start_stop_easytronic-2018-araba-57589
# https://www.fordikinciel.com/opel-corsa-14_essentia_start_stop_easytronic-2018-araba-57589
# 136.500
# OPEL
# CORSA
# 2018
# 28.533
# Otomatik
# Benzin
# Beyaz
# 90
# 1398
# 1088
# Hatchback
# Otomobil
# Binek
# ford-mustang-50_ti_vct_v8_gt-2015-araba-57639
# https://www.fordikinciel.com/ford-mustang-50_ti_vct_v8_gt-2015-araba-57639
# 1.210.000
# FORD
# MUSTANG
# 2015
# 12.311
# Manuel
# Benzin
# Kırmızı
# 415
# 4951
# 1732
# Coupe
# Otomobil
# Binek
# ford-focus-16_tdci_trend_x-2017-araba-57694
# https://www.fordikinciel.com/ford-focus-16_tdci_trend_x-2017-araba-57694
# 157.500
# FORD
# FOCUS
# 2017
# 126.407
# Manuel
# Dizel
# Beyaz
# 95
# 1560
# 1345
# Sedan
# Otomobil
# Binek
# ford-focus-15_tdci_trend_x_powershift-2018-araba-57899
# https://www.fordikinciel.com/ford-focus-15_tdci_trend_x_powershift-2018-araba-57899
# 192.500
# FORD
# FOCUS
# 2018
# 92.206
# Otomatik
# Dizel
# Beyaz
# 120
# 1499
# 1358
# Sedan
# Otomobil
# Binek
# ford-focus-15_tdci_trend_x_powershift-2018-araba-57901
# https://www.fordikinciel.com/ford-focus-15_tdci_trend_x_powershift-2018-araba-57901
# 192.500
# FORD
# FOCUS
# 2018
# 84.039
# Otomatik
# Dizel
# Beyaz
# 120
# 1499
# 1358
# Sedan
# Otomobil
# Binek
# audi-a4-avant_20_tdi_multitronic-2011-araba-58047
# https://www.fordikinciel.com/audi-a4-avant_20_tdi_multitronic-2011-araba-58047
# 231.500
# AUDI
# A4
# 2011
# 148.684
# Otomatik
# Dizel
# Beyaz
# 143
# 1968
# 1575
# Wagon-Kombi
# Otomobil
# Binek
# ford-focus-15_tdci_st_line-2018-araba-48278
# https://www.fordikinciel.com/ford-focus-15_tdci_st_line-2018-araba-48278
# 345.000
# FORD
# FOCUS
# 2018
# 15.103
# Otomatik
# Dizel
# -
# 118
# 0
# 0
# Hatchback
# Otomobil
# Binek
# ford-fiesta-16_titanium_powershift-2013-araba-49516
# https://www.fordikinciel.com/ford-fiesta-16_titanium_powershift-2013-araba-49516
# 145.000
# FORD
# FIESTA
# 2013
# 50.000
# Otomatik
# Benzin
# -
# 105
# 1596
# 1098
# Hatchback
# Otomobil
# Binek
# ford-focus-16_ti_vct_titanium_powershift-2017-araba-49881
# https://www.fordikinciel.com/ford-focus-16_ti_vct_titanium_powershift-2017-araba-49881
# 195.000
# FORD
# FOCUS
# 2017
# 37.250
# Otomatik
# Benzin
# Kırmızı
# 125
# 1596
# 1296
# Sedan
# Otomobil
# Binek
# ford-tourneo_connect-15_tdci_swb_titanium_powershift-2015-araba-50224
# https://www.fordikinciel.com/ford-tourneo_connect-15_tdci_swb_titanium_powershift-2015-araba-50224
# 160.000
# FORD
# CONNECT
# 2015
# 130.000
# Otomatik
# Dizel
# -
# 118
# 1499
# 1477
# Wagon-Kombi
# Kamyonet
# Ticari

# %%
list_of_cars
# Out:
# [['298.500',
#   'AUDI',
#   'A3',
#   '2018',
#   '62.317',
#   'Otomatik',
#   'Dizel',
#   'Lacivert',
#   '109',
#   '1598',
#   '1290',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['231.500',
#   'VOLKSWAGEN',
#   'POLO',
#   '2019',
#   '15.426',
#   'Otomatik',
#   'Dizel',
#   'Gri',
#   '90',
#   '1598',
#   '1179',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['272.500',
#   'FORD',
#   'KUGA',
#   '2018',
#   '35.106',
#   'Otomatik',
#   'Dizel',
#   'Gri',
#   '118',
#   '1499',
#   '1605',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['137.500',
#   'PEUGEOT',
#   '208',
#   '2016',
#   '98.690',
#   'Otomatik',
#   'Benzin',
#   'DİĞER',
#   '82',
#   '1199',
#   '1168',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['166.000',
#   'FORD',
#   'FOCUS',
#   '2017',
#   '56.075',
#   'Manuel',
#   'Benzin',
#   'Beyaz',
#   '125',
#   '1596',
#   '1269',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['465.000',
#   'ROVER',
#   'DISCOVERY',
#   '2010',
#   '182.087',
#   'Otomatik',
#   'Dizel',
#   'Beyaz',
#   '245',
#   '2993',
#   '2583',
#   'Wagon-Kombi',
#   'Otomobil',
#   'Binek'],
#  ['533.000',
#   'MERCEDES',
#   'SERISI',
#   '2018',
#   '33.122',
#   'Otomatik',
#   'Benzin',
#   'Beyaz',
#   '184',
#   '1598',
#   '1485',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['231.500',
#   'OPEL',
#   'ASTRA',
#   '2020',
#   '36.955',
#   'Otomatik',
#   'Dizel',
#   'Kırmızı',
#   '122',
#   '1496',
#   '0',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['273.500',
#   'SKODA',
#   'SUPERB',
#   '2016',
#   '89.976',
#   'Otomatik',
#   'Dizel',
#   'Beyaz',
#   '120',
#   '1598',
#   '1480',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['236.500',
#   'FORD',
#   'MONDEO',
#   '2017',
#   '109.203',
#   'Manuel',
#   'Dizel',
#   'Kırmızı',
#   '115',
#   '1560',
#   '1493',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['264.500',
#   'SKODA',
#   'OCTAVIA',
#   '2017',
#   '74.285',
#   'Otomatik',
#   'Dizel',
#   'Beyaz',
#   '110',
#   '1598',
#   '1245',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['136.500',
#   'OPEL',
#   'CORSA',
#   '2018',
#   '28.533',
#   'Otomatik',
#   'Benzin',
#   'Beyaz',
#   '90',
#   '1398',
#   '1088',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['1.210.000',
#   'FORD',
#   'MUSTANG',
#   '2015',
#   '12.311',
#   'Manuel',
#   'Benzin',
#   'Kırmızı',
#   '415',
#   '4951',
#   '1732',
#   'Coupe',
#   'Otomobil',
#   'Binek'],
#  ['157.500',
#   'FORD',
#   'FOCUS',
#   '2017',
#   '126.407',
#   'Manuel',
#   'Dizel',
#   'Beyaz',
#   '95',
#   '1560',
#   '1345',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['192.500',
#   'FORD',
#   'FOCUS',
#   '2018',
#   '92.206',
#   'Otomatik',
#   'Dizel',
#   'Beyaz',
#   '120',
#   '1499',
#   '1358',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['192.500',
#   'FORD',
#   'FOCUS',
#   '2018',
#   '84.039',
#   'Otomatik',
#   'Dizel',
#   'Beyaz',
#   '120',
#   '1499',
#   '1358',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['231.500',
#   'AUDI',
#   'A4',
#   '2011',
#   '148.684',
#   'Otomatik',
#   'Dizel',
#   'Beyaz',
#   '143',
#   '1968',
#   '1575',
#   'Wagon-Kombi',
#   'Otomobil',
#   'Binek'],
#  ['345.000',
#   'FORD',
#   'FOCUS',
#   '2018',
#   '15.103',
#   'Otomatik',
#   'Dizel',
#   '-',
#   '118',
#   '0',
#   '0',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['145.000',
#   'FORD',
#   'FIESTA',
#   '2013',
#   '50.000',
#   'Otomatik',
#   'Benzin',
#   '-',
#   '105',
#   '1596',
#   '1098',
#   'Hatchback',
#   'Otomobil',
#   'Binek'],
#  ['195.000',
#   'FORD',
#   'FOCUS',
#   '2017',
#   '37.250',
#   'Otomatik',
#   'Benzin',
#   'Kırmızı',
#   '125',
#   '1596',
#   '1296',
#   'Sedan',
#   'Otomobil',
#   'Binek'],
#  ['160.000',
#   'FORD',
#   'CONNECT',
#   '2015',
#   '130.000',
#   'Otomatik',
#   'Dizel',
#   '-',
#   '118',
#   '1499',
#   '1477',
#   'Wagon-Kombi',
#   'Kamyonet',
#   'Ticari']]

# %%
len(list_of_cars)
# Out:
# 21
